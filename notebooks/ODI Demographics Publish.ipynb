# %% [markdown]
# # Guinea-Bissau Demographics: Population
# ---
# Glenn Abastillas | April 7, 2020
#
# ## General Population
#
# Column `UN_2020_E` : 2020 UN Estimate

# %%
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ## General Population
#
# Column `UN_2020_E` : 2020 UN Estimate

# %%
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ---
